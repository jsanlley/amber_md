# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

# %%
mmgbsa_csv = './mpro_del_docking_output/7UR9_CDD-1845_Docking_MMGBSA_Constraints.csv'
mmgbsa_df = pd.read_csv(mmgbsa_csv)
mmgbsa_df
# Out:
#                                  Title  docking score  glide energy  \
# 0                      Naphtha_Control        -10.939       -77.108
# 1                    Trifluoro_Control        -10.756       -73.166
# 2                    3-delta-enelactam        -10.476       -70.186
# 3                    4-gamma-enelactam         -9.320       -67.140
# 4                     3-delta-lactam-S        -10.799       -68.165
# 5                     2-gamma-lactam-R         -7.745       -63.186
# 6                    5-delta-enelactam         -9.743       -67.771
# 7             2-methyl-delta-enelactam         -7.355       -69.825
# 8           2-methyl-delta-enelactam-R        -10.192       -69.315
# 9                    3-gamma-enelactam         -9.821       -65.390
# 10                   2-delta-enelactam         -9.486       -66.673
# 11             2-methyl-gamma-lactam-R        -10.372       -68.444
# 12                    3-gamma-lactam-S         -8.340       -64.174
# 13                    5-delta-lactam-S         -9.324       -64.764
# 14                    3-delta-lactam-R         -9.672       -64.457
# 15                   2-gamma-enelactam         -9.375       -66.350
# 16             4-methyl-gamma-lactam-R         -7.201       -59.815
# 17                    2-delta-lactam-S         -8.777       -63.376
# 18          4-methyl-delta-enelactam-R         -8.650       -60.759
# 19  11b_Control_3-fluorophenyl_Control         -9.108       -60.642
# 20                         11a_Control         -8.741       -58.424
# 21                    4-delta-lactam-R         -8.007       -57.189
# 22             3-methyl-gamma-lactam-S         -8.713       -61.701
# 23             5-methyl-delta-lactam-S         -7.170       -55.253
# 24             4-methyl-gamma-lactam-S         -6.895       -53.575
# 25                    5-delta-lactam-R         -8.574       -55.570
# 26             3-methyl-gamma-lactam-R         -7.802       -57.268
# 27                   4-delta-enelactam         -6.345       -57.418
# 28            5-methyl-delta-enelactam         -8.354       -61.677
# 29             2-methyl-gamma-lactam-S         -7.211       -53.213
# 30            3-methyl-delta-enelactam         -6.154       -55.125
# 31                    4-gamma-lactam-S         -7.666       -57.086
# 32          3-methyl-delta-enelactam-R         -6.406       -53.817
# 33            4-methyl-gamma-enelactam         -7.557       -51.501
# 34            3-methyl-gamma-enelactam         -8.850       -58.625
# 35             3-methyl-delta-lactam-S         -7.636       -53.126
# 36            4-methyl-delta-enelactam         -5.874       -54.552
# 37            2-methyl-gamma-enelactam         -6.454       -51.705
# 38             4-methyl-delta-lactam-S         -6.727       -50.398
# 39                    3-gamma-lactam-R         -7.135       -52.771
# 40                    2-gamma-lactam-S         -5.886       -51.849
# 41          5-methyl-delta-enelactam-R         -5.432       -52.081
# 42                    2-delta-lactam-R         -6.215       -48.891
# 43                    4-gamma-lactam-R         -5.395       -53.567
# 44             2-methyl-delta-lactam-S         -4.197       -55.825
# 45                    4-delta-lactam-S         -2.623       -37.857
#
#     glide emodel                                             SMILES  \
# 0       -128.670  c1cccc(c12)cncc2-c(n3CCCC(=O)NC)nc(c34)cccc4C(...
# 1       -121.447  c1cccc(c12)cncc2-c(n3CCCC(=O)NC)nc(c34)cccc4C(...
# 2       -111.510  CNC(=O)CCCn1c(-c2cc(=O)[nH]cc2)nc(c13)cccc3C(=...
# 3       -103.965  CNC(=O)CCCn1c(C2=NC(=O)C=C2)nc(c13)cccc3C(=O)N...
# 4       -105.332  CNC(=O)CCCn1c(-c2cc(=O)[nH]cc2)nc(c13)cccc3C(=...
# 5        -83.356  CNC(=O)CCCn1c([C@H](C2=O)CCN2)nc(c13)cccc3C(=O...
# 6       -105.790  CNC(=O)CCCn1c(-c2cccc(=O)[nH]2)nc(c13)cccc3C(=...
# 7        -91.007  CNC(=O)CCCn1c(Cc2c(=O)[nH]ccc2)nc(c13)cccc3C(=...
# 8       -110.570  CNC(=O)CCCn1c(Cc2c(=O)[nH]ccc2)nc(c13)cccc3C(=...
# 9        -98.908  CNC(=O)CCCn1c(C2=CC(=O)N=C2)nc(c13)cccc3C(=O)N...
# 10      -105.144  CNC(=O)CCCn1c(-c2c(=O)[nH]ccc2)nc(c13)cccc3C(=...
# 11      -107.528  CNC(=O)CCCn1c(C[C@H](C2=O)CCN2)nc(c13)cccc3C(=...
# 12       -84.385  CNC(=O)CCCn1c([C@@H](CC2=O)CN2)nc(c13)cccc3C(=...
# 13       -99.769  CNC(=O)CCCn1c(-c2cccc(=O)[nH]2)nc(c13)cccc3C(=...
# 14      -101.112  CNC(=O)CCCn1c(-c2cc(=O)[nH]cc2)nc(c13)cccc3C(=...
# 15      -103.132  CNC(=O)CCCn1c(C2=CC=NC2=O)nc(c13)cccc3C(=O)N[C...
# 16       -77.841  CNC(=O)CCCn1c(C[C@H](N2)CCC2=O)nc(c13)cccc3C(=...
# 17       -94.579  CNC(=O)CCCn1c(-c2c(=O)[nH]ccc2)nc(c13)cccc3C(=...
# 18       -92.757  CNC(=O)CCCn1c(Cc2ccc(=O)[nH]c2)nc(c13)cccc3C(=...
# 19       -89.358  N1CC[C@H](C1=O)C[C@@H](C=O)NC(=O)[C@H](Cc2cc(F...
# 20       -82.826  N1CC[C@H](C1=O)C[C@@H](C=O)NC(=O)[C@H](CC2CCCC...
# 21       -81.483  CNC(=O)CCCn1c(-c2ccc(=O)[nH]c2)nc(c13)cccc3C(=...
# 22       -89.890  CNC(=O)CCCn1c(C[C@@H](CC2=O)CN2)nc(c13)cccc3C(...
# 23       -72.842  CNC(=O)CCCn1c(Cc2cccc(=O)[nH]2)nc(c13)cccc3C(=...
# 24       -71.553  CNC(=O)CCCn1c(C[C@@H](N2)CCC2=O)nc(c13)cccc3C(...
# 25       -81.587  CNC(=O)CCCn1c(-c2cccc(=O)[nH]2)nc(c13)cccc3C(=...
# 26       -81.045  CNC(=O)CCCn1c(C[C@H](CC2=O)CN2)nc(c13)cccc3C(=...
# 27       -65.393  CNC(=O)CCCn1c(-c2ccc(=O)[nH]c2)nc(c13)cccc3C(=...
# 28       -89.618  CNC(=O)CCCn1c(Cc2cccc(=O)[nH]2)nc(c13)cccc3C(=...
# 29       -75.220  CNC(=O)CCCn1c(C[C@@H](C2=O)CCN2)nc(c13)cccc3C(...
# 30       -75.528  CNC(=O)CCCn1c(Cc2cc(=O)[nH]cc2)nc(c13)cccc3C(=...
# 31       -80.795  CNC(=O)CCCn1c([C@@H](N2)CCC2=O)nc(c13)cccc3C(=...
# 32       -72.158  CNC(=O)CCCn1c(Cc2cc(=O)[nH]cc2)nc(c13)cccc3C(=...
# 33       -77.648  CNC(=O)CCCn1c(CC2=NC(=O)C=C2)nc(c13)cccc3C(=O)...
# 34       -90.103  CNC(=O)CCCn1c(CC2=CC(=O)N=C2)nc(c13)cccc3C(=O)...
# 35       -73.543  CNC(=O)CCCn1c(Cc2cc(=O)[nH]cc2)nc(c13)cccc3C(=...
# 36       -76.927  CNC(=O)CCCn1c(Cc2ccc(=O)[nH]c2)nc(c13)cccc3C(=...
# 37       -75.800  CNC(=O)CCCn1c(CC2=CC=NC2=O)nc(c13)cccc3C(=O)N[...
# 38       -73.412  CNC(=O)CCCn1c(Cc2ccc(=O)[nH]c2)nc(c13)cccc3C(=...
# 39       -72.490  CNC(=O)CCCn1c([C@H](CC2=O)CN2)nc(c13)cccc3C(=O...
# 40       -70.296  CNC(=O)CCCn1c([C@@H](C2=O)CCN2)nc(c13)cccc3C(=...
# 41       -66.757  CNC(=O)CCCn1c(Cc2cccc(=O)[nH]2)nc(c13)cccc3C(=...
# 42       -67.539  CNC(=O)CCCn1c(-c2c(=O)[nH]ccc2)nc(c13)cccc3C(=...
# 43       -69.809  CNC(=O)CCCn1c([C@H](N2)CCC2=O)nc(c13)cccc3C(=O...
# 44       -58.260  CNC(=O)CCCn1c(Cc2c(=O)[nH]ccc2)nc(c13)cccc3C(=...
# 45       -36.242  CNC(=O)CCCn1c(-c2ccc(=O)[nH]c2)nc(c13)cccc3C(=...
#
#     MMGBSA dG Bind  MMGBSA dG Bind(NS)  glide gscore
# 0           -89.00              -91.33       -10.940
# 1           -81.00              -84.16       -10.757
# 2           -78.01              -81.49       -10.476
# 3           -77.77              -79.80        -9.320
# 4           -71.85              -78.19       -10.799
# 5           -69.71              -75.97        -7.745
# 6           -71.65              -75.35        -9.743
# 7           -63.08              -75.18        -7.355
# 8           -67.02              -74.76       -10.192
# 9           -70.00              -74.56        -9.821
# 10          -69.02              -74.51        -9.486
# 11          -66.89              -73.80       -10.372
# 12          -66.52              -73.78        -8.340
# 13          -65.46              -73.75        -9.324
# 14          -67.76              -73.72        -9.672
# 15          -68.69              -71.94        -9.375
# 16          -58.29              -71.85        -7.201
# 17          -63.42              -70.98        -8.777
# 18          -64.98              -70.53        -8.650
# 19          -61.45              -69.70        -9.109
# 20          -60.04              -69.56        -8.742
# 21          -55.53              -68.90        -8.007
# 22          -55.41              -67.95        -8.713
# 23          -45.26              -67.67        -7.170
# 24          -54.18              -67.14        -6.895
# 25          -54.16              -63.91        -8.574
# 26          -55.34              -63.44        -7.802
# 27          -55.08              -62.90        -6.345
# 28          -44.07              -62.84        -8.354
# 29          -47.82              -61.64        -7.211
# 30          -51.57              -61.39        -6.154
# 31          -49.64              -60.76        -7.666
# 32          -47.71              -58.38        -6.406
# 33          -41.08              -57.87        -7.557
# 34          -42.16              -57.04        -8.850
# 35          -35.62              -54.51        -7.636
# 36          -40.20              -54.46        -5.874
# 37          -37.86              -54.27        -6.454
# 38          -44.66              -54.07        -6.727
# 39          -44.70              -51.55        -7.150
# 40          -45.61              -50.10        -5.886
# 41          -34.14              -47.34        -5.432
# 42          -34.64              -46.66        -6.215
# 43          -35.75              -44.90        -5.412
# 44          -26.71              -40.95        -4.197
# 45          -28.31              -37.28        -2.623

# %%
mmgbsa_df_2 = mmgbsa_df.merge(mmgbsa_df_2[['Title']], on='Title', how='right')
mmgbsa_df_2.sort_values(by=['MMGBSA dG Bind(NS)'])
# Out:
#                        Title  docking score  glide energy  glide emodel  \
# 1          3-delta-enelactam        -10.476       -70.186      -111.510
# 5          4-gamma-enelactam         -9.320       -67.140      -103.965
# 0           3-delta-lactam-S        -10.799       -68.165      -105.332
# 2          5-delta-enelactam         -9.743       -67.771      -105.790
# 8           3-gamma-lactam-S         -8.340       -64.174       -84.385
# 4           5-delta-lactam-S         -9.324       -64.764       -99.769
# 3           3-delta-lactam-R         -9.672       -64.457      -101.112
# 11   4-methyl-gamma-lactam-R         -7.201       -59.815       -77.841
# 9           4-delta-lactam-R         -8.007       -57.189       -81.483
# 7    3-methyl-gamma-lactam-S         -8.713       -61.701       -89.890
# 13         4-delta-enelactam         -6.345       -57.418       -65.393
# 10  4-methyl-gamma-enelactam         -7.557       -51.501       -77.648
# 6   3-methyl-gamma-enelactam         -8.850       -58.625       -90.103
# 12   4-methyl-delta-lactam-S         -6.727       -50.398       -73.412
#
#                                                SMILES  MMGBSA dG Bind  \
# 1   CNC(=O)CCCn1c(-c2cc(=O)[nH]cc2)nc(c13)cccc3C(=...          -78.01
# 5   CNC(=O)CCCn1c(C2=NC(=O)C=C2)nc(c13)cccc3C(=O)N...          -77.77
# 0   CNC(=O)CCCn1c(-c2cc(=O)[nH]cc2)nc(c13)cccc3C(=...          -71.85
# 2   CNC(=O)CCCn1c(-c2cccc(=O)[nH]2)nc(c13)cccc3C(=...          -71.65
# 8   CNC(=O)CCCn1c([C@@H](CC2=O)CN2)nc(c13)cccc3C(=...          -66.52
# 4   CNC(=O)CCCn1c(-c2cccc(=O)[nH]2)nc(c13)cccc3C(=...          -65.46
# 3   CNC(=O)CCCn1c(-c2cc(=O)[nH]cc2)nc(c13)cccc3C(=...          -67.76
# 11  CNC(=O)CCCn1c(C[C@H](N2)CCC2=O)nc(c13)cccc3C(=...          -58.29
# 9   CNC(=O)CCCn1c(-c2ccc(=O)[nH]c2)nc(c13)cccc3C(=...          -55.53
# 7   CNC(=O)CCCn1c(C[C@@H](CC2=O)CN2)nc(c13)cccc3C(...          -55.41
# 13  CNC(=O)CCCn1c(-c2ccc(=O)[nH]c2)nc(c13)cccc3C(=...          -55.08
# 10  CNC(=O)CCCn1c(CC2=NC(=O)C=C2)nc(c13)cccc3C(=O)...          -41.08
# 6   CNC(=O)CCCn1c(CC2=CC(=O)N=C2)nc(c13)cccc3C(=O)...          -42.16
# 12  CNC(=O)CCCn1c(Cc2ccc(=O)[nH]c2)nc(c13)cccc3C(=...          -44.66
#
#     MMGBSA dG Bind(NS)  glide gscore
# 1               -81.49       -10.476
# 5               -79.80        -9.320
# 0               -78.19       -10.799
# 2               -75.35        -9.743
# 8               -73.78        -8.340
# 4               -73.75        -9.324
# 3               -73.72        -9.672
# 11              -71.85        -7.201
# 9               -68.90        -8.007
# 7               -67.95        -8.713
# 13              -62.90        -6.345
# 10              -57.87        -7.557
# 6               -57.04        -8.850
# 12              -54.07        -6.727

# %%
#top delta lactam
delta_lactam_mmgbsa_df = mmgbsa_df_2.loc[mmgbsa_df_2["Title"].str.contains("delta-lactam")]["MMGBSA dG Bind"]

#top delta enelactam
delta_enelactam_mmgbsa_df = mmgbsa_df_2.loc[mmgbsa_df_2["Title"].str.contains("delta-enelactam")]["MMGBSA dG Bind"]

#top gamma lactam
gamma_lactam_mmgbsa_df = mmgbsa_df_2.loc[mmgbsa_df_2["Title"].str.contains("gamma-lactam")]["MMGBSA dG Bind"]

#top gamma enelactam
gamma_enelactam_mmgbsa_df = mmgbsa_df_2.loc[mmgbsa_df_2["Title"].str.contains("gamma-enelactam")]["MMGBSA dG Bind"]
# Out:
# 0    -71.85
# 3    -67.76
# 4    -65.46
# 9    -55.53
# 12   -44.66
# Name: MMGBSA dG Bind, dtype: float64

# %%
control = trifluoro_control_mmgbsa
avidd_df = mmgbsa_df_2.loc[mmgbsa_df_2['Title'].str.contains("delta-lactam")]["MMGBSA dG Bind"]

avidd_df.plot.bar(x="Title",y=["MMGBSA dG Bind"],rot=90,color='gold',figsize=(12,8),fontsize=14)

plt.axhline(control,linestyle="--",color="black",)
plt.gca().invert_yaxis()
plt.tight_layout()
plt.ylabel("kcal/mol",fontsize=18)
plt.title("MMGBSA Binding Energy (kcal/mol)",fontsize=18)
plt.xlabel("")
plt.legend(("Trifluoro control",'MMGBSA Binding Energy'))
plt.plot()
# Out:
# []

# %%
#Control compounds (native ligands)
control_df = mmgbsa_df[mmgbsa_df["Title"].str.contains("Control")]

#Control Glide score (from Glide SP)
trifluoro_control_ge = float(control_df.loc[control_df["Title"].str.contains("Trifluoro")]["glide energy"])
naphtha_control_ge = float(control_df.loc[control_df["Title"].str.contains("Naphtha")]["glide energy"])
lactam_control_ge = float(control_df.loc[control_df["Title"].str.contains("11a")]["glide energy"])

#Control Docking score (from Glide SP)
trifluoro_control_ds = float(control_df.loc[control_df["Title"].str.contains("Trifluoro")]["docking score"])
naphtha_control_ds = float(control_df.loc[control_df["Title"].str.contains("Naphtha")]["docking score"])
lactam_control_ds = float(control_df.loc[control_df["Title"].str.contains("11a")]["docking score"])

#Control MMGBSA scores
trifluoro_control_mmgbsa = float(control_df.loc[control_df["Title"].str.contains("Trifluoro")]["MMGBSA dG Bind"])
naphtha_control_mmgbsa = float(control_df.loc[control_df["Title"].str.contains("Naphtha")]["MMGBSA dG Bind"])
lactam_control_mmgbsa = float(control_df.loc[control_df["Title"].str.contains("11a")]["MMGBSA dG Bind"])

# %%
#Function for plotting either ds or mmgbsa for a given df
def plot_df(avidd_df,energy,plot_color):
    
    #Final Plot for Glide Energy (Glide Energy)
    if energy == 'ge':
        control = trifluoro_control_ge
        avidd_df = avidd_df.sort_values(by=["glide energy"])

        avidd_df.plot.bar(x="Title",
                          y=["glide energy"],
                          rot=90,
                          color=plot_color,figsize=(12,8),
                         fontsize=18 )

        plt.axhline(control,linestyle="--",color="black",)
        plt.gca().invert_yaxis()
        plt.tight_layout()
        plt.ylabel("kcal/mol")
        plt.title("Glide Energy Scores")
        plt.legend(("Trifluoro control",'Glide Energy'))
        plt.xlabel("")
        plt.plot()
        
    #Final Plot for Docking Score (Glide Energy)
    elif energy == 'ds':
        control = trifluoro_control_ds
        avidd_df = avidd_df.sort_values(by=["docking score"])

        avidd_df.plot.bar(x="Title",
                          y=["docking score"],
                          rot=90,
                          color=plot_color,figsize=(12,8),
                         fontsize=18)

        plt.axhline(control,linestyle="--",color="black",)
        plt.gca().invert_yaxis()
        plt.tight_layout()
        plt.ylabel("Score",fontsize=18)
        plt.title("Docking Scores",fontsize=18)
        plt.legend(("Trifluoro control",'Docking Score'))
        plt.xlabel("")
        plt.plot()
        
    #Final Plot for MMGBSA Energy (Binding Energy)    
    elif energy == 'mmgbsa':
        control = trifluoro_control_mmgbsa
        avidd_df = avidd_df.sort_values(by=["MMGBSA dG Bind"])

        avidd_df.plot.bar(x="Title",
                          y=["MMGBSA dG Bind"],
                          rot=90,
                          color=plot_color,
                         figsize=(12,8),
                         fontsize=14)
        
        plt.axhline(control,linestyle="--",color="black",)
        plt.gca().invert_yaxis()
        plt.tight_layout()
        plt.ylabel("kcal/mol",fontsize=18)
        plt.title("MMGBSA Binding Energy (kcal/mol)",fontsize=18)
        plt.xlabel("")
        plt.legend(("Trifluoro control",'MMGBSA Binding Energy'))
        plt.plot()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 plot_df(delta_lactam_mmgbsa_df,'mmgbsa','gray')
#
# Cell In[99], line 47, in plot_df(avidd_df, energy, plot_color)
#      45 elif energy == 'mmgbsa':
#      46     control = trifluoro_control_mmgbsa
# ---> 47     avidd_df = avidd_df.sort_values(by=["MMGBSA dG Bind"])
#      49     avidd_df.plot.bar(x="Title",
#      50                       y=["MMGBSA dG Bind"],
#      51                       rot=90,
#      52                       color=plot_color,
#      53                      figsize=(12,8),
#      54                      fontsize=14)
#      56     plt.axhline(control,linestyle="--",color="black",)
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# TypeError: Series.sort_values() got an unexpected keyword argument 'by'

# %%
plot_df(mmgbsa_df_2,'mmgbsa','gray')

# %%
#Control Compounds
#plot_df(control_df,'ds','gold')
#plot_df(control_df, 'ge','gold')
plot_df(control_df,'mmgbsa','gold')

# %%
#Original compounds
avidd_list = ['4-gamma-enelactam','2-gamma-lactam-R',
              '2-gamma-lactam-S','4-gamma-lactam-R',
              '4-gamma-lactam-S','2-delta-enelactam',
              '4-delta-enelactam']

avidd_df = mmgbsa_df[mmgbsa_df["Title"].isin(avidd_list)]

# %%
#plot avidd compounds(avidd compounds,'ds')
#plot_df(avidd_df, 'ge',"gray")
avidd_mmgbsa_plot = plot_df(avidd_df,'mmgbsa',"gray")

# %%
#plot_df(avidd_df,'ds')
#plot_df(avidd_df, 'ge','gray')
#plot_df(avidd_df,'mmgbsa','gray')

colors = {"gamma-lactam": 'red',
         "gamma-enelactam": 'blue',
         "delta-enelactam": 'green',
          "delta-lactam": 'pink',
         "Control": 'gold'}

categorical_variable = ["red" if "gamma-lactam" in i else 
                       "blue" if "gamma-enelactam" in i else 
                       "green" if "delta-enelactam" in i else
                        "pink" if "delta-lactam" in i else
                        "gold" if "Control" in i else "black" for i in avidd_df["Title"]]

#ax = avidd_df.plot.bar(x="Title",y='glide energy',color = categorical_variable,rot=45)
ax = mmgbsa_df_2.plot.bar(x="Title",y='MMGBSA dG Bind',color = categorical_variable,rot=45)

legend_handles = [
    mpatches.Patch(color=colors['gamma-lactam'], label="Gamma-lactam"),
    mpatches.Patch(color=colors['gamma-enelactam'], label="Gamma-enelactam"),
    mpatches.Patch(color=colors['delta-enelactam'], label="Delta-enelactam"),
]

#plt.legend(("Trifluoro control (-51.68 kcal/mol)"))
ax.legend(handles=legend_handles,loc='lower right')
plt.axhline(naphtha_control_mmgbsa,linestyle="--",color="black")


plt.xlabel("")
plt.ylabel("kcal/mol")
plt.gca().invert_yaxis()
plt.plot()
# Out:
# []

# %%
#delta-enelactam  (2,3,4,5)
delta_enelactam = mmgbsa_df[mmgbsa_df["Title"].str.contains("delta-enelactam")]
delta_enelactam

#plot_df(delta_enelactam,'ds')
#plot_df(delta_enelactam, 'ge',"green")
plot_df(delta_enelactam,'mmgbsa',"green")

# %%
#gamma-enelactam  (2,3,4)
gamma_enelactam = mmgbsa_df[mmgbsa_df["Title"].str.contains("gamma-enelactam")]
gamma_enelactam

#plot_df(gamma_enelactam,'ds')
#plot_df(gamma_enelactam,'ge',"blue")
plot_df(gamma_enelactam,'mmgbsa',"blue")

# %%
#gamma-lactam    (2,3,4)
gamma_lactam = mmgbsa_df[mmgbsa_df["Title"].str.contains("gamma-lactam")]
gamma_enelactam

#plot_df(gamma_lactam,'ds')
plot_df(gamma_lactam,'mmgbsa','red')
#plot_df(gamma_lactam,'ge','red')

# %%
#top 5 compounds
top_emodel = mmgbsa_df_2.sort_values(by=["MMGBSA dG Bind"]).head(8)

colors = {"gamma-lactam": 'red',
         "gamma-enelactam": 'blue',
         "delta-enelactam": 'green',
          "delta-lactam": 'gold',
         "Control": 'black'}

categorical_variable = ["red" if "gamma-lactam" in i else 
                       "blue" if "gamma-enelactam" in i else 
                       "green" if "delta-enelactam" in i else 
                        "gold" if "delta-lactam" in i else
                        "black" if "Control" in i else "black" for i in top_emodel["Title"]]


ax = top_emodel.plot.bar(x="Title",
                         y='MMGBSA dG Bind',
                         color = categorical_variable,
                         rot=60,
                        figsize=(12,8),
                        fontsize=14)
plt.axhline(naphtha_control_mmgbsa,linestyle="--",color="black",)

legend_handles = [
    mpatches.Patch(color=colors['gamma-lactam'], label="Gamma-lactam"),
    mpatches.Patch(color=colors['gamma-enelactam'], label="Gamma-enelactam"),
    mpatches.Patch(color=colors['delta-enelactam'], label="Delta-enelactam"),
    mpatches.Patch(color=colors['delta-lactam'], label="Delta-lactam")
    #mpatches.Patch(color=colors['Control'], label="Control"),
]

ax.legend(handles=legend_handles,loc='upper right')
plt.xlabel("")
plt.gca().invert_yaxis()
plt.ylabel("MMGBSA kcal/mol",fontsize=22)
plt.ylim(-50,-100)
plt.plot()
# Out:
# []

# %%
colors = {"gamma-lactam": 'red',
         "gamma-enelactam": 'blue',
         "delta-enelactam": 'green',
          "delta-lactam": 'chartreuse',
         "Control": 'gold'}

categorical_variable = ["red" if "gamma-lactam" in i else 
                       "blue" if "gamma-enelactam" in i else 
                       "green" if "delta-enelactam" in i else 
                        "chartreuse" if "delta-lactam" in i else
                        "gold" if "Control" in i else "black" for i in mmgbsa_df["Title"]]


ax = mmgbsa_df.plot.scatter(x=["MMGBSA dG Bind"], 
                            y=["glide energy"], 
                            c=categorical_variable, 
                            rot=90,
                            s=16)

#plt.axhline(trifluoro_control_ge,linestyle="--",color="grey")
plt.axvline(trifluoro_control_mmgbsa,linestyle="--",color="maroon")
plt.axvline(naphtha_control_mmgbsa,linestyle="--",color="black")

legend_handles = [
    mpatches.Patch(color=colors['gamma-lactam'], label="Gamma-lactam"),
    mpatches.Patch(color=colors['gamma-enelactam'], label="Gamma-enelactam"),
    mpatches.Patch(color=colors['delta-enelactam'], label="Delta-enelactam"),
    mpatches.Patch(color=colors['Control'], label="Control"),
]

ax.legend(handles=legend_handles,loc='upper left')
plt.plot()
# Out:
# []

# %%
#delta-enelactam  (2,3,4,5)
delta_lactam = mmgbsa_df[mmgbsa_df["Title"].str.contains("delta-lactam")]
delta_lactam

#plot_df(delta_enelactam,'ds')
#plot_df(delta_lactam, 'ge',"violet")
plot_df(delta_lactam,'mmgbsa',"chartreuse")

# %%
#top 5 delta enelactam + top 5 delta lactam

top_delta = [delta_lactam.sort_values(by=["MMGBSA dG Bind"]).head(5),
            delta_enelactam.sort_values(by=["MMGBSA dG Bind"]).head(5)]

top_delta_df = pd.concat(top_delta).sort_values(by=["MMGBSA dG Bind"]).head(5)

colors = {"gamma-lactam": 'red',
         "gamma-enelactam": 'blue',
         "delta-enelactam": 'green',
          "delta-lactam": 'chartreuse',
         "Control": 'black'}

categorical_variable = ["red" if "gamma-lactam" in i else 
                       "blue" if "gamma-enelactam" in i else 
                       "green" if "delta-enelactam" in i else 
                        "chartreuse" if "delta-lactam" in i else
                        "black" if "Control" in i else "black" for i in top_delta_df["Title"]]


ax = top_delta_df.plot.bar(x="Title",
                         y='MMGBSA dG Bind',
                         color = categorical_variable,
                         rot=45,
                        figsize=(12,8),
                        fontsize=14)
plt.axhline(naphtha_control_mmgbsa,linestyle="--",color="black",)

legend_handles = [
    #mpatches.Patch(color=colors['gamma-lactam'], label="Gamma-lactam"),
    #mpatches.Patch(color=colors['gamma-enelactam'], label="Gamma-enelactam"),
    mpatches.Patch(color=colors['delta-enelactam'], label="Delta-enelactam"),
    mpatches.Patch(color=colors['delta-lactam'], label="Delta-lactam"),
    #mpatches.Patch(color=colors['Control'], label="Control"),
]

ax.legend(handles=legend_handles,loc='upper right')
plt.xlabel("")
plt.gca().invert_yaxis()
plt.ylabel("kcal/mol",fontsize=22)
plt.ylim(-50,-100)
plt.plot()
# Out:
# []

# %%
#top 5 gamma enelactam vs. top 5 delta lactam
top_gamma = [gamma_lactam.sort_values(by=["MMGBSA dG Bind"]).head(5),
            gamma_enelactam.sort_values(by=["MMGBSA dG Bind"]).head(5)]

top_gamma_df = pd.concat(top_gamma).sort_values(by=["MMGBSA dG Bind"]).head(5)

colors = {"gamma-lactam": 'red',
         "gamma-enelactam": 'blue',
         "delta-enelactam": 'green',
          "delta-lactam": 'chartreuse',
         "Control": 'black'}

categorical_variable = ["red" if "gamma-lactam" in i else 
                       "blue" if "gamma-enelactam" in i else 
                       "green" if "delta-enelactam" in i else 
                        "chartreuse" if "delta-lactam" in i else
                        "black" if "Control" in i else "black" for i in top_gamma_df["Title"]]


ax = top_gamma_df.plot.bar(x="Title",
                         y='MMGBSA dG Bind',
                         color = categorical_variable,
                         rot=45,
                        figsize=(12,8),
                        fontsize=14)
plt.axhline(naphtha_control_mmgbsa,linestyle="--",color="black",)

legend_handles = [
    mpatches.Patch(color=colors['gamma-lactam'], label="Gamma-lactam"),
    mpatches.Patch(color=colors['gamma-enelactam'], label="Gamma-enelactam"),
    #mpatches.Patch(color=colors['delta-enelactam'], label="Delta-enelactam"),
    #patches.Patch(color=colors['delta-lactam'], label="Delta-enelactam"),
    #mpatches.Patch(color=colors['Control'], label="Control"),
]

ax.legend(handles=legend_handles,loc='upper right')
plt.xlabel("")
plt.gca().invert_yaxis()
plt.ylabel("kcal/mol",fontsize=22)
plt.ylim(-50,-100)
plt.plot()
# Out:
# []
