# %%
import os
import glob

path = '/net/gpfs-amarolab/jsanlleyhernandez/mpro_md'
systems = ['1733','1819']
pdb_list = []

for system in systems:
    pdb_path = glob.glob(path+'/mpro_'+system+'/2*/*solvated.pdb')

    for pdb in pdb_path:
        print(pdb)

print(len(pdb_path))
# Out:
# /net/gpfs-amarolab/jsanlleyhernandez/mpro_md/mpro_1733/2-sysprep/mpro_1733_solvated.pdb
# /net/gpfs-amarolab/jsanlleyhernandez/mpro_md/mpro_1819/2-sysprep/mpro_solvated.pdb
# 1
