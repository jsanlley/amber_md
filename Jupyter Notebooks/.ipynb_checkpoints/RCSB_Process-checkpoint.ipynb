# %%
import os
import glob
import pandas as pd

# %%
path = '/home/jsanlleyhernandez/Downloads/rcsb_pdb_custom_report_20231009123012.csv'

df = pd.read_csv(path,header=1)
print(df.columns)
df.info
# Out:
# Index(['Entry ID', 'pH', 'DOI', 'Deposited Model Count',
#        'Total Number of Polymer Instances (Chains)',
#        'Total Number of Polymer Residues per Deposited Model',
#        'Molecular Weight per Deposited Model', 'Resolution (Å)',
#        'Structure Title', 'Source Organism', 'Unnamed: 10'],
#       dtype='object')
# <bound method DataFrame.info of     Entry ID   pH                         DOI  Deposited Model Count  \
# 0       7LKE  7.5  10.1038/s42003-022-03090-9                    1.0
# 1       7LKD  7.5  10.1038/s42003-022-03090-9                    1.0
# 2       7NF5  6.5       10.3390/ijms222111779                    1.0
# 3       7BE7  8.5       10.3390/ijms222111779                    1.0
# 4       7BGP  8.5       10.3390/ijms222111779                    1.0
# ..       ...  ...                         ...                    ...
# 322     8DMD  6.5    10.1021/acs.jcim.2c01377                    1.0
# ...
